# %%
from pathlib import Path
from pydub import AudioSegment
from concurrent.futures import ThreadPoolExecutor
from pydub.utils import which


# Hàm chuyển đổi một file từ .webm sang .wav
def convert_to_wav(file: Path, output_dir: Path) -> str:
    try:
        print(f"Đang xử lý file: {file.name}")
        # Kiểm tra file tồn tại
        if not file.exists():
            return f"File không tồn tại: {file.name}"
        
        # Đọc file .webm và chuyển đổi
        audio = AudioSegment.from_file(file, format="webm")
        output_file = output_dir / f"{file.stem}.wav"
        audio.export(output_file, format="wav")
        
        # Kiểm tra file đầu ra
        if output_file.exists():
            return f"Chuyển đổi thành công: {file.name} -> {output_file.name}"
        else:
            return f"Lỗi: Không thể tạo file đầu ra cho {file.name}"
    except Exception as e:
        return f"Lỗi khi xử lý file {file.name}: {e}"

def main():
    # Đường dẫn đến thư mục chứa file .webm
    input_dir = Path('Dataset/cleaned_webm')
    audio_files = list(input_dir.glob('*.webm'))

    if not audio_files:
        print("Không tìm thấy file .webm nào trong thư mục!")
        return
    
    # Thư mục đích để lưu file .wav
    output_dir = Path('Dataset/converted_wav')
    output_dir.mkdir(parents=True, exist_ok=True)

    # Sử dụng ThreadPoolExecutor để xử lý song song
    print("Bắt đầu chuyển đổi file...")
    with ThreadPoolExecutor() as executor:
        results = executor.map(convert_to_wav, audio_files, [output_dir] * len(audio_files))
    
    # Hiển thị kết quả
    for result in results:
        print(result)

if __name__ == "__main__":
    main()
# Out:
# Bắt đầu chuyển đổi file...
# Đang xử lý file: recorded_audio.webm
# Đang xử lý file: recorded_audio_02jmPGL.webm
# Đang xử lý file: recorded_audio_03k88ok.webm
# Đang xử lý file: recorded_audio_08AxQ5T.webm
# Đang xử lý file: recorded_audio_08oFo0W.webm
# Đang xử lý file: recorded_audio_0bJpmSM.webm
# Đang xử lý file: recorded_audio_0cAbXnW.webm
# Đang xử lý file: recorded_audio_0CQyKuq.webm
# Đang xử lý file: recorded_audio_0gNmgd9.webm
# Đang xử lý file: recorded_audio_0J52MEJ.webm
# Đang xử lý file: recorded_audio_0kxS3Qd.webm
# Đang xử lý file: recorded_audio_0myWVxZ.webm
# Đang xử lý file: recorded_audio_0NKAqN3.webm
# Đang xử lý file: recorded_audio_0od48Xz.webm
# Đang xử lý file: recorded_audio_0qU1vGN.webm
# Đang xử lý file: recorded_audio_0rJ1um4.webm
# Đang xử lý file: recorded_audio_0sXcBMX.webm
# Đang xử lý file: recorded_audio_0UbW71l.webm
# Đang xử lý file: recorded_audio_0uf1UXQ.webm
# Đang xử lý file: recorded_audio_0VeK4SK.webm
# Đang xử lý file: recorded_audio_0W65we5.webm
# Đang xử lý file: recorded_audio_12Z4Zr5.webm
# Đang xử lý file: recorded_audio_13GbSCo.webm
# Đang xử lý file: recorded_audio_167fAwe.webm
# Đang xử lý file: recorded_audio_16eHFWy.webm
# Đang xử lý file: recorded_audio_1BybzGg.webm
# Đang xử lý file: recorded_audio_1EeZukq.webm
# Đang xử lý file: recorded_audio_1epmLVT.webm
# Đang xử lý file: recorded_audio_1EViUfP.webm
# Đang xử lý file: recorded_audio_1gPzPKV.webm
# Đang xử lý file: recorded_audio_1IiYyfT.webm
# Đang xử lý file: recorded_audio_1iXbvx9.webm
# Đang xử lý file: recorded_audio_1l2mrE9.webm
# Đang xử lý file: recorded_audio_1L61v1Y.webm
# Đang xử lý file: recorded_audio_1nVyndP.webm
# Đang xử lý file: recorded_audio_1O3aLVp.webm
# Đang xử lý file: recorded_audio_1P2gd1r.webm
# Đang xử lý file: recorded_audio_1VdoWnf.webm
# Đang xử lý file: recorded_audio_1vl4Wis.webm
# Đang xử lý file: recorded_audio_1XeReJj.webm
# Đang xử lý file: recorded_audio_1Xqn3kh.webm
# Đang xử lý file: recorded_audio_1YJLT4A.webm
# Đang xử lý file: recorded_audio_20EaVyk.webm
# Đang xử lý file: recorded_audio_26VOmmm.webm
# Đang xử lý file: recorded_audio_2bB5eWe.webm
# Đang xử lý file: recorded_audio_2dHgS8V.webm
# Đang xử lý file: recorded_audio_2IB9FUv.webm
# Đang xử lý file: recorded_audio_2kF45RP.webm
# Đang xử lý file: recorded_audio_2L15dOV.webm
# Đang xử lý file: recorded_audio_2mk2K7P.webm
# Đang xử lý file: recorded_audio_2NAFWv6.webm
# Đang xử lý file: recorded_audio_2nfFyRI.webm
# Đang xử lý file: recorded_audio_2OOOPay.webm
# Đang xử lý file: recorded_audio_2pBOkRh.webm
# Đang xử lý file: recorded_audio_2qcr5bv.webm
# Đang xử lý file: recorded_audio_2QDgQB1.webm
# Đang xử lý file: recorded_audio_2R0kv6M.webm
# Đang xử lý file: recorded_audio_2SgXCLH.webm
# Đang xử lý file: recorded_audio_2U3vgyn.webm
# Đang xử lý file: recorded_audio_2Voe93U.webm
# Đang xử lý file: recorded_audio_2xhDSn8.webmĐang xử lý file: recorded_audio_2xM09yx.webm
#
# Đang xử lý file: recorded_audio_2xmBUM0.webm
# Đang xử lý file: recorded_audio_2yelJJK.webm
# Đang xử lý file: recorded_audio_2Z7TlZC.webm
# Đang xử lý file: recorded_audio_32DUbkt.webm
# Đang xử lý file: recorded_audio_3aCYrjz.webm
# Đang xử lý file: recorded_audio_3cqiafG.webm
# Đang xử lý file: recorded_audio_3eE8Svc.webm
# Đang xử lý file: recorded_audio_3EsISUd.webm
# Đang xử lý file: recorded_audio_3FsVrXl.webm
# Đang xử lý file: recorded_audio_3HcoloC.webm
# Đang xử lý file: recorded_audio_3hFySLU.webm
# Đang xử lý file: recorded_audio_3jFqrS1.webm
# Đang xử lý file: recorded_audio_3np80RT.webm
# Đang xử lý file: recorded_audio_3OfNWcH.webm
# Đang xử lý file: recorded_audio_3paUWu5.webm
# Đang xử lý file: recorded_audio_3QFxQfi.webm
# Đang xử lý file: recorded_audio_3RY1UWN.webm
# Đang xử lý file: recorded_audio_3vfUYP9.webm
# Đang xử lý file: recorded_audio_3yiuO0X.webm
# Đang xử lý file: recorded_audio_3Z7msHZ.webm
# Đang xử lý file: recorded_audio_3Z8o9aq.webm
# Đang xử lý file: recorded_audio_40VLzQ9.webm
# Đang xử lý file: recorded_audio_447LbNm.webm
# Đang xử lý file: recorded_audio_46cWls4.webm
# Đang xử lý file: recorded_audio_46rxHNG.webm
# Đang xử lý file: recorded_audio_4aQam1J.webm
# Đang xử lý file: recorded_audio_4dCo0BL.webm
# Đang xử lý file: recorded_audio_4dylUpD.webm
# Đang xử lý file: recorded_audio_4EnrJ7B.webm
# Đang xử lý file: recorded_audio_4ErMBG8.webm
# Đang xử lý file: recorded_audio_4FDwfxN.webm
# Đang xử lý file: recorded_audio_4HoFTXz.webm
# Đang xử lý file: recorded_audio_4k585HZ.webm
# Đang xử lý file: recorded_audio_4kRe4qD.webm
# Đang xử lý file: recorded_audio_4lFriPj.webm
# Đang xử lý file: recorded_audio_4ncKAFC.webm
# Đang xử lý file: recorded_audio_4NG1DzP.webm
# Đang xử lý file: recorded_audio_4pPRLNk.webm
# Đang xử lý file: recorded_audio_4th2FeU.webm
# Đang xử lý file: recorded_audio_4tqBiye.webm
# Đang xử lý file: recorded_audio_4U19dbp.webm
# Đang xử lý file: recorded_audio_4yq1hHa.webm
# Đang xử lý file: recorded_audio_4Ywygpz.webm
# Đang xử lý file: recorded_audio_5405BKJ.webm
# Đang xử lý file: recorded_audio_59AlNza.webm
# Đang xử lý file: recorded_audio_59GM3ji.webm
# Đang xử lý file: recorded_audio_59nMHfK.webm
# Đang xử lý file: recorded_audio_5ClQ8qN.webm
# Đang xử lý file: recorded_audio_5CnYd5h.webm
# Đang xử lý file: recorded_audio_5fEV5hj.webm
# Đang xử lý file: recorded_audio_5gXIQEp.webm
# Đang xử lý file: recorded_audio_5mAMArA.webm
# Đang xử lý file: recorded_audio_5OaYCoi.webm
# Đang xử lý file: recorded_audio_5q6h6UP.webm
# Đang xử lý file: recorded_audio_5TJDqtV.webm
# Đang xử lý file: recorded_audio_5Z52NXy.webm
# Đang xử lý file: recorded_audio_5zeSaFB.webm
# Đang xử lý file: recorded_audio_5zyOTaW.webm
# Đang xử lý file: recorded_audio_62f2nPB.webm
# Đang xử lý file: recorded_audio_67HIOvl.webm
# Đang xử lý file: recorded_audio_68kBy4q.webm
# Đang xử lý file: recorded_audio_6cG2Zts.webm
# Đang xử lý file: recorded_audio_6E7NXhb.webm
# Đang xử lý file: recorded_audio_6emr1kD.webm
# Đang xử lý file: recorded_audio_6EvwghX.webm
# Đang xử lý file: recorded_audio_6g0EJdS.webm
# Đang xử lý file: recorded_audio_6GyryxM.webm
# Đang xử lý file: recorded_audio_6IOLLkf.webm
# Đang xử lý file: recorded_audio_6iONTuF.webm
# Đang xử lý file: recorded_audio_6IvNo9Q.webm
# Đang xử lý file: recorded_audio_6ivw08K.webm
# Đang xử lý file: recorded_audio_6lrGxUj.webmĐang xử lý file: recorded_audio_6mzj0bG.webm
#
# Đang xử lý file: recorded_audio_6N7Omzm.webm
# Đang xử lý file: recorded_audio_6nL98Sy.webm
# Đang xử lý file: recorded_audio_6o6gT8f.webm
# Đang xử lý file: recorded_audio_6oXuj0U.webm
# Đang xử lý file: recorded_audio_6pnYSyG.webm
# Đang xử lý file: recorded_audio_6quJ5LT.webm
# Đang xử lý file: recorded_audio_6SUI9Y5.webm
# Đang xử lý file: recorded_audio_6verQdd.webm
# Đang xử lý file: recorded_audio_6WGhVvg.webm
# Đang xử lý file: recorded_audio_6XnyBw2.webm
# Đang xử lý file: recorded_audio_6ZTSnaW.webm
# Đang xử lý file: recorded_audio_70lCGDM.webm
# Đang xử lý file: recorded_audio_71VUtmn.webm
# Đang xử lý file: recorded_audio_74aLLmg.webm
# Đang xử lý file: recorded_audio_74DlP9M.webm
# Đang xử lý file: recorded_audio_74dvVMV.webm
# Đang xử lý file: recorded_audio_79NOSGu.webm
# Đang xử lý file: recorded_audio_7aAzWg9.webm
# Đang xử lý file: recorded_audio_7ha7uMR.webm
# Đang xử lý file: recorded_audio_7haeQeP.webm
# Đang xử lý file: recorded_audio_7ipAeYF.webm
# Đang xử lý file: recorded_audio_7iWrTgN.webm
# Đang xử lý file: recorded_audio_7jVjPoY.webm
# Đang xử lý file: recorded_audio_7KgiZXg.webm
# Đang xử lý file: recorded_audio_7lUPRTC.webm
# Đang xử lý file: recorded_audio_7mJONfh.webm
# Đang xử lý file: recorded_audio_7nZXjUt.webm
# Đang xử lý file: recorded_audio_7uatzGV.webm
# Đang xử lý file: recorded_audio_85wBrWi.webm
# Đang xử lý file: recorded_audio_88KoZjr.webm
# Đang xử lý file: recorded_audio_8AcCwf7.webm
# Đang xử lý file: recorded_audio_8ATvWhC.webm
# Đang xử lý file: recorded_audio_8aWgkuk.webm
# Đang xử lý file: recorded_audio_8fs5av0.webm
# Đang xử lý file: recorded_audio_8jlleSY.webm
# Đang xử lý file: recorded_audio_8Kz1gZi.webm
# Đang xử lý file: recorded_audio_8LfSMo9.webm
# Đang xử lý file: recorded_audio_8M1Umhy.webm
# Đang xử lý file: recorded_audio_8mcFdit.webm
# Đang xử lý file: recorded_audio_8nTfpVQ.webm
# Đang xử lý file: recorded_audio_8NtPCMB.webm
# Đang xử lý file: recorded_audio_8NzTFPM.webm
# Đang xử lý file: recorded_audio_8s6uEgC.webm
# Đang xử lý file: recorded_audio_8xSc49k.webm
# Đang xử lý file: recorded_audio_8xSxnMx.webm
# Đang xử lý file: recorded_audio_8YdBZ83.webm
# Đang xử lý file: recorded_audio_8YiU4IU.webm
# Đang xử lý file: recorded_audio_8YWwPBA.webm
# Đang xử lý file: recorded_audio_952NVQE.webm
# Đang xử lý file: recorded_audio_96uTNli.webm
# Đang xử lý file: recorded_audio_9CAK3Rk.webm
# Đang xử lý file: recorded_audio_9D8KrU8.webm
# Đang xử lý file: recorded_audio_9dOKLL0.webm
# Đang xử lý file: recorded_audio_9f7I8q2.webm
# Đang xử lý file: recorded_audio_9fGNhKv.webm
# Đang xử lý file: recorded_audio_9H4Wu4T.webm
# Đang xử lý file: recorded_audio_9iH29ey.webm
# Đang xử lý file: recorded_audio_9JGZMuz.webm
# Đang xử lý file: recorded_audio_9lLqk2c.webm
# Đang xử lý file: recorded_audio_9Mias7w.webm
# Đang xử lý file: recorded_audio_9oAobei.webm
# Đang xử lý file: recorded_audio_9oVADMr.webm
# Đang xử lý file: recorded_audio_9Q3xH9m.webm
# Đang xử lý file: recorded_audio_9QXvddF.webm
# Đang xử lý file: recorded_audio_9rvuj0l.webm
# Đang xử lý file: recorded_audio_9USS5MO.webm
# Đang xử lý file: recorded_audio_9vnWtrO.webm
# Đang xử lý file: recorded_audio_9wuTsW2.webm
# Đang xử lý file: recorded_audio_9wWVwyP.webm
# Đang xử lý file: recorded_audio_9x6nZhj.webm
# Đang xử lý file: recorded_audio_9ypA5O1.webm
# Đang xử lý file: recorded_audio_9ZDJqc8.webm
# Đang xử lý file: recorded_audio_9ZWk7in.webm
# Đang xử lý file: recorded_audio_A0MwoOW.webm
# Đang xử lý file: recorded_audio_a11i3gz.webm
# Đang xử lý file: recorded_audio_A3J7s6a.webm
# Đang xử lý file: recorded_audio_a6Y2gNE.webm
# Đang xử lý file: recorded_audio_ab1eugB.webm
# Đang xử lý file: recorded_audio_AbSllBP.webm
# Đang xử lý file: recorded_audio_Abu6kpX.webm
# Đang xử lý file: recorded_audio_aC7nvFi.webm
# Đang xử lý file: recorded_audio_aDNcd43.webm
# Đang xử lý file: recorded_audio_ae7wN2L.webm
# Đang xử lý file: recorded_audio_Ag2DSbI.webm
# Đang xử lý file: recorded_audio_AgufqzX.webm
# Đang xử lý file: recorded_audio_aiqpL8x.webm
# Đang xử lý file: recorded_audio_AKiOumJ.webm
# Đang xử lý file: recorded_audio_ALC3jdp.webm
# Đang xử lý file: recorded_audio_AlS8lq8.webm
# Đang xử lý file: recorded_audio_AmYl0LL.webm
# Đang xử lý file: recorded_audio_aN64oLR.webm
# Đang xử lý file: recorded_audio_AoaJumj.webm
# Đang xử lý file: recorded_audio_aOwfvmJ.webm
# Đang xử lý file: recorded_audio_aQPPtQ0.webm
# Đang xử lý file: recorded_audio_aR3Tczf.webm
# Đang xử lý file: recorded_audio_ArpwYVF.webm
# Đang xử lý file: recorded_audio_ARsazfy.webm
# Đang xử lý file: recorded_audio_AugOMHb.webm
# Đang xử lý file: recorded_audio_auJJ6iO.webm
# Đang xử lý file: recorded_audio_avUCnL0.webm
# Đang xử lý file: recorded_audio_avW1Rio.webm
# Đang xử lý file: recorded_audio_aWazV29.webm
# Đang xử lý file: recorded_audio_AwO4UV2.webm
# Đang xử lý file: recorded_audio_aWse4Hc.webm
# Đang xử lý file: recorded_audio_axZudqU.webm
# Đang xử lý file: recorded_audio_aYhSTXH.webm
# Đang xử lý file: recorded_audio_aYxOLb2.webm
# Đang xử lý file: recorded_audio_AzDIAJy.webm
# Đang xử lý file: recorded_audio_AzngQPa.webm
# Đang xử lý file: recorded_audio_B0R8YoW.webm
# Đang xử lý file: recorded_audio_B0zMLXP.webm
# Đang xử lý file: recorded_audio_B9aaeyy.webm
# Đang xử lý file: recorded_audio_b9U2oLv.webm
# Đang xử lý file: recorded_audio_BANKTAw.webm
# Đang xử lý file: recorded_audio_BBGqB4N.webm
# Đang xử lý file: recorded_audio_BCewNFH.webm
# Đang xử lý file: recorded_audio_BcljmDc.webm
# Đang xử lý file: recorded_audio_BcsAZgw.webm
# Đang xử lý file: recorded_audio_BCtylg3.webm
# Đang xử lý file: recorded_audio_bd09O3W.webm
# Đang xử lý file: recorded_audio_bea0Myj.webm
# Đang xử lý file: recorded_audio_BEv8ooJ.webm
# Đang xử lý file: recorded_audio_BeWoDZl.webm
# Đang xử lý file: recorded_audio_bfChwyE.webm
# Đang xử lý file: recorded_audio_bfedNqV.webm
# Đang xử lý file: recorded_audio_bG5ZKYt.webm
# Đang xử lý file: recorded_audio_bGsWflM.webm
# Đang xử lý file: recorded_audio_BguWtP7.webm
# Đang xử lý file: recorded_audio_Bh8bZou.webm
# Đang xử lý file: recorded_audio_BHjYdu6.webm
# Đang xử lý file: recorded_audio_bhubyiY.webm
# Đang xử lý file: recorded_audio_BiAPuBP.webm
# Đang xử lý file: recorded_audio_BKF3Ufv.webm
# Đang xử lý file: recorded_audio_BKjIYPm.webm
# Đang xử lý file: recorded_audio_bl7ugiU.webm
# Đang xử lý file: recorded_audio_BMp15gK.webm
# Đang xử lý file: recorded_audio_BoFqGL1.webm
# Đang xử lý file: recorded_audio_BOQQG4u.webm
# Đang xử lý file: recorded_audio_bqDJooz.webm
# Đang xử lý file: recorded_audio_BQjphOt.webm
# Đang xử lý file: recorded_audio_BrtV02W.webm
# Đang xử lý file: recorded_audio_bSftIZ9.webm
# Đang xử lý file: recorded_audio_BSXWxcv.webm
# Đang xử lý file: recorded_audio_BTTEWK8.webm
# Đang xử lý file: recorded_audio_bU3ht0G.webm
# Đang xử lý file: recorded_audio_bvYl8w2.webm
# Đang xử lý file: recorded_audio_BwTRXNh.webm
# Đang xử lý file: recorded_audio_bxHEBya.webm
# Đang xử lý file: recorded_audio_BXS2576.webm
# Đang xử lý file: recorded_audio_BzBnYKL.webm
# Đang xử lý file: recorded_audio_C3aqnQR.webm
# Đang xử lý file: recorded_audio_C4Ht3R9.webm
# Đang xử lý file: recorded_audio_C6rTUEu.webm
# Đang xử lý file: recorded_audio_C72syQb.webm
# Đang xử lý file: recorded_audio_CaEzjdS.webm
# Đang xử lý file: recorded_audio_Cbs16FN.webm
# Đang xử lý file: recorded_audio_cCPaScn.webm
# Đang xử lý file: recorded_audio_CdvlrFV.webm
# Đang xử lý file: recorded_audio_ce2lDcA.webm
# Đang xử lý file: recorded_audio_cenHauK.webm
# Đang xử lý file: recorded_audio_CFbicnc.webm
# Đang xử lý file: recorded_audio_CHEvFMf.webm
# Đang xử lý file: recorded_audio_chNkCoz.webm
# Đang xử lý file: recorded_audio_chVR6Kb.webm
# Đang xử lý file: recorded_audio_ckcIIMp.webm
# Đang xử lý file: recorded_audio_ckkGJ8v.webm
# Đang xử lý file: recorded_audio_ClgardF.webm
# Đang xử lý file: recorded_audio_ClTMAvl.webm
# Đang xử lý file: recorded_audio_Cmyk7xR.webm
# Đang xử lý file: recorded_audio_CN2hxd4.webm
# Đang xử lý file: recorded_audio_cn8xucN.webm
# Đang xử lý file: recorded_audio_CNZ5A4Q.webm
# Đang xử lý file: recorded_audio_CoDKkFU.webm
# Đang xử lý file: recorded_audio_cPmT239.webm
# Đang xử lý file: recorded_audio_cqngLL4.webm
# Đang xử lý file: recorded_audio_cQrm4PG.webm
# Đang xử lý file: recorded_audio_CSHw1MY.webmĐang xử lý file: recorded_audio_CUfX2el.webm
#
# Đang xử lý file: recorded_audio_cUqz8y8.webm
# Đang xử lý file: recorded_audio_cUVnXWo.webm
# Đang xử lý file: recorded_audio_cV8mKKr.webm
# Đang xử lý file: recorded_audio_cWaI2pW.webm
# Đang xử lý file: recorded_audio_cWE81zz.webm
# Đang xử lý file: recorded_audio_cwOm6rL.webm
# Đang xử lý file: recorded_audio_CwvHv0s.webm
# Đang xử lý file: recorded_audio_cYdXMSA.webm
# Đang xử lý file: recorded_audio_cZJo5dX.webm
# Đang xử lý file: recorded_audio_d1482gw.webm
# Đang xử lý file: recorded_audio_d2hV4BQ.webm
# Đang xử lý file: recorded_audio_d46aQln.webm
# Đang xử lý file: recorded_audio_D4JzxK6.webm
# Đang xử lý file: recorded_audio_d4TCa5D.webm
# Đang xử lý file: recorded_audio_d6Yhhg2.webm
# Đang xử lý file: recorded_audio_d80ocWY.webm
# Đang xử lý file: recorded_audio_D943nCS.webm
# Đang xử lý file: recorded_audio_d9lKR5z.webm
# Đang xử lý file: recorded_audio_DaLZxuh.webm
# Đang xử lý file: recorded_audio_DAvJf4q.webm
# Đang xử lý file: recorded_audio_dbATP7v.webm
# Đang xử lý file: recorded_audio_dBGBtCA.webm
# Đang xử lý file: recorded_audio_DCh46K5.webm
# Đang xử lý file: recorded_audio_ddSbZbi.webm
# Đang xử lý file: recorded_audio_DdUVAgO.webm
# Đang xử lý file: recorded_audio_dEDHHqZ.webm
# Đang xử lý file: recorded_audio_dejbFKk.webm
# Đang xử lý file: recorded_audio_DexeblK.webm
# Đang xử lý file: recorded_audio_DEz8jAt.webm
# Đang xử lý file: recorded_audio_DFefOy0.webm
# Đang xử lý file: recorded_audio_dFrZ1mG.webm
# Đang xử lý file: recorded_audio_Dfs7Mea.webm
# Đang xử lý file: recorded_audio_DHazw6s.webm
# Đang xử lý file: recorded_audio_DjcdTJR.webm
# Đang xử lý file: recorded_audio_DkkGakk.webm
# Đang xử lý file: recorded_audio_DL7lHx4.webm
# Đang xử lý file: recorded_audio_dlY76Eh.webm
# Đang xử lý file: recorded_audio_DMJxZwx.webm
# Đang xử lý file: recorded_audio_DnajsHS.webm
# Đang xử lý file: recorded_audio_dNoyDRy.webm
# Đang xử lý file: recorded_audio_DNrVCqU.webm
# Đang xử lý file: recorded_audio_do0kb9R.webm
# Đang xử lý file: recorded_audio_dQuM6HC.webm
# Đang xử lý file: recorded_audio_DqzvYaS.webm
# Đang xử lý file: recorded_audio_DsfmPNv.webm
# Đang xử lý file: recorded_audio_dtexXHi.webm
# Đang xử lý file: recorded_audio_DTKHnUN.webm
# Đang xử lý file: recorded_audio_DtQEv1X.webm
# Đang xử lý file: recorded_audio_DUH2Cdk.webm
# Đang xử lý file: recorded_audio_DuhrC4M.webm
# Đang xử lý file: recorded_audio_DVCtQZM.webm
# Đang xử lý file: recorded_audio_DvJfMoN.webm
# Đang xử lý file: recorded_audio_DvWfwDl.webm
# Đang xử lý file: recorded_audio_dwZYS9N.webm
# Đang xử lý file: recorded_audio_dx0q9mS.webm
# Đang xử lý file: recorded_audio_dX5cGpK.webm
# Đang xử lý file: recorded_audio_dxBmBdE.webm
# Đang xử lý file: recorded_audio_dxcEeZ0.webm
# Đang xử lý file: recorded_audio_DXUtVqD.webm
# Đang xử lý file: recorded_audio_dZH2VsX.webm
# Đang xử lý file: recorded_audio_DzKOzXK.webm
# Đang xử lý file: recorded_audio_E0bIcte.webm
# Đang xử lý file: recorded_audio_e4Jr1WN.webm
# Đang xử lý file: recorded_audio_E6ds5Jg.webm
# Đang xử lý file: recorded_audio_e7C4hFL.webm
# Đang xử lý file: recorded_audio_eaBgSte.webm
# Đang xử lý file: recorded_audio_Eay9bRj.webm
# Đang xử lý file: recorded_audio_EEP0cPG.webm
# Đang xử lý file: recorded_audio_eeXTMFT.webm
# Đang xử lý file: recorded_audio_Eg1nIgQ.webm
# Đang xử lý file: recorded_audio_EgJ82qL.webm
# Đang xử lý file: recorded_audio_EHfN6Pn.webm
# Đang xử lý file: recorded_audio_ehUac6O.webm
# Đang xử lý file: recorded_audio_eHYgy6f.webm
# Đang xử lý file: recorded_audio_eIIbZXF.webm
# Đang xử lý file: recorded_audio_eJ5qN3r.webm
# Đang xử lý file: recorded_audio_EJ5vFfs.webmĐang xử lý file: recorded_audio_ej7C6C8.webm
#
# Đang xử lý file: recorded_audio_ekebBzk.webm
# Đang xử lý file: recorded_audio_EkglHH3.webm
# Đang xử lý file: recorded_audio_EkObKxu.webm
# Đang xử lý file: recorded_audio_ELX7XBF.webm
# Đang xử lý file: recorded_audio_eMrj0w4.webm
# Đang xử lý file: recorded_audio_EmZxZn3.webm
# Đang xử lý file: recorded_audio_ENb5Lpm.webm
# Đang xử lý file: recorded_audio_EoYShFb.webm
# Đang xử lý file: recorded_audio_ePuBOHp.webm
# Đang xử lý file: recorded_audio_EQtO89a.webm
# Đang xử lý file: recorded_audio_eRAuhEB.webm
# Đang xử lý file: recorded_audio_eVCnmzH.webm
# Đang xử lý file: recorded_audio_evnMe5Q.webm
# Đang xử lý file: recorded_audio_eVrrwJZ.webm
# Đang xử lý file: recorded_audio_EWn4z82.webm
# Đang xử lý file: recorded_audio_ExgdiIg.webm
# Đang xử lý file: recorded_audio_EYJ5SGB.webm
# Đang xử lý file: recorded_audio_F01Kz7P.webm
# Đang xử lý file: recorded_audio_F1qyOCq.webmĐang xử lý file: recorded_audio_F39yV2u.webm
# Đang xử lý file: recorded_audio_F73gPfX.webm
#
# Đang xử lý file: recorded_audio_f7G7XGL.webm
# Đang xử lý file: recorded_audio_fb1tdYU.webm
# Đang xử lý file: recorded_audio_fCBtcy4.webm
# Đang xử lý file: recorded_audio_FcxtLDW.webm
# Đang xử lý file: recorded_audio_Fdn7EqA.webm
# Đang xử lý file: recorded_audio_FeompJs.webm
# Đang xử lý file: recorded_audio_FesYDMF.webm
# Đang xử lý file: recorded_audio_feX7eqh.webm
# Đang xử lý file: recorded_audio_FfSibsQ.webm
# Đang xử lý file: recorded_audio_fglp0iy.webm
# Đang xử lý file: recorded_audio_fHTxGgM.webm
# Đang xử lý file: recorded_audio_fjIyIK3.webm
# Đang xử lý file: recorded_audio_fjuCjCL.webm
# Đang xử lý file: recorded_audio_fjw2EA6.webm
# Đang xử lý file: recorded_audio_flZhdTA.webm
# Đang xử lý file: recorded_audio_fN0ILBC.webm
# Đang xử lý file: recorded_audio_fnmD2s8.webm
# Đang xử lý file: recorded_audio_fo1fFZ6.webm
# Đang xử lý file: recorded_audio_frXlXlo.webm
# Đang xử lý file: recorded_audio_FspWN5Z.webm
# Đang xử lý file: recorded_audio_Ft2n8QG.webm
# Đang xử lý file: recorded_audio_FtPLAaG.webm
# Đang xử lý file: recorded_audio_ftw4QjU.webm
# Đang xử lý file: recorded_audio_fUwxcB7.webmĐang xử lý file: recorded_audio_fw80py0.webm
# Đang xử lý file: recorded_audio_fxWrRon.webm
#
# Đang xử lý file: recorded_audio_fydwaY7.webm
# Đang xử lý file: recorded_audio_FzhrP05.webm
# Đang xử lý file: recorded_audio_g0I6984.webm
# Đang xử lý file: recorded_audio_G0qvYkx.webm
# Đang xử lý file: recorded_audio_g2Eo93k.webm
# Đang xử lý file: recorded_audio_g3CqEho.webm
# Đang xử lý file: recorded_audio_G3mVXv8.webm
# Đang xử lý file: recorded_audio_G482BgW.webm
# Đang xử lý file: recorded_audio_g4Wjn5d.webm
# Đang xử lý file: recorded_audio_G6390Oy.webm
# Đang xử lý file: recorded_audio_g6a5vG1.webm
# Đang xử lý file: recorded_audio_G77qFgX.webm
# Đang xử lý file: recorded_audio_g7BxhJf.webm
# Đang xử lý file: recorded_audio_g9Psjl0.webm
# Đang xử lý file: recorded_audio_GaDeF5I.webm
# Đang xử lý file: recorded_audio_gaqKVv0.webm
# Đang xử lý file: recorded_audio_gAu0WAZ.webm
# Đang xử lý file: recorded_audio_GBSBgOr.webm
# Đang xử lý file: recorded_audio_GCKGayv.webm
# Đang xử lý file: recorded_audio_GdbPve7.webm
# Đang xử lý file: recorded_audio_GdU0q1n.webm
# Đang xử lý file: recorded_audio_gfI8NsN.webm
# Đang xử lý file: recorded_audio_gFRTDbQ.webm
# Đang xử lý file: recorded_audio_gh5PZX9.webm
# Đang xử lý file: recorded_audio_ghJj0Zb.webm
# Đang xử lý file: recorded_audio_ghtmPKz.webm
# Đang xử lý file: recorded_audio_Gl9TxLu.webm
# Đang xử lý file: recorded_audio_gMEofF4.webm
# Đang xử lý file: recorded_audio_GmSuhu1.webm
# Đang xử lý file: recorded_audio_gMW3sLS.webm
# Đang xử lý file: recorded_audio_GnEjH7C.webm
# Đang xử lý file: recorded_audio_GoZNJWh.webm
# Đang xử lý file: recorded_audio_gP36NXW.webm
# Đang xử lý file: recorded_audio_Gqa3z7g.webm
# Đang xử lý file: recorded_audio_gQFsHd0.webm
# Đang xử lý file: recorded_audio_GQseOat.webm
# Đang xử lý file: recorded_audio_GquvI3g.webm
# Đang xử lý file: recorded_audio_GrC4KwO.webm
# Đang xử lý file: recorded_audio_gTgn9c0.webm
# Đang xử lý file: recorded_audio_gw2IdnC.webm
# Đang xử lý file: recorded_audio_GWgQxJx.webm
# Đang xử lý file: recorded_audio_GxjQfmb.webm
# Đang xử lý file: recorded_audio_Gy2SZCq.webm
# Đang xử lý file: recorded_audio_gzdiEvX.webm
# Đang xử lý file: recorded_audio_H4e8CWV.webm
# Đang xử lý file: recorded_audio_HAJ107h.webm
# Đang xử lý file: recorded_audio_Hbda1lV.webm
# Đang xử lý file: recorded_audio_hcVzwCM.webm
# Đang xử lý file: recorded_audio_HE2opws.webm
# Đang xử lý file: recorded_audio_He9Mect.webm
# Đang xử lý file: recorded_audio_hfd9zDl.webm
# Đang xử lý file: recorded_audio_hfp98ZO.webm
# Đang xử lý file: recorded_audio_HFq6ViM.webm
# Đang xử lý file: recorded_audio_hfuMv9Y.webm
# Đang xử lý file: recorded_audio_HgoGvdB.webm
# Đang xử lý file: recorded_audio_hGXu5Jg.webm
# Đang xử lý file: recorded_audio_HHddZEn.webm
# Đang xử lý file: recorded_audio_hj0SUNy.webm
# Đang xử lý file: recorded_audio_hL6A79X.webm
# Đang xử lý file: recorded_audio_HmkJYxE.webm
# Đang xử lý file: recorded_audio_hMzoUtW.webm
# Đang xử lý file: recorded_audio_HneggnM.webm
# Đang xử lý file: recorded_audio_hpODKYw.webm
# Đang xử lý file: recorded_audio_HQ09mgK.webm
# Đang xử lý file: recorded_audio_HQJnnuX.webm
# Đang xử lý file: recorded_audio_hQjnxla.webm
# Đang xử lý file: recorded_audio_HQnAft4.webm
# Đang xử lý file: recorded_audio_hRRJEcc.webm
# Đang xử lý file: recorded_audio_hS7CJm6.webm
# Đang xử lý file: recorded_audio_HTa6Fcm.webm
# Đang xử lý file: recorded_audio_hTiLQGF.webm
# Đang xử lý file: recorded_audio_HTIomoc.webm
# Đang xử lý file: recorded_audio_HtmMpIJ.webm
# Đang xử lý file: recorded_audio_HVmrp2p.webm
# Đang xử lý file: recorded_audio_HvVRmTD.webm
# Đang xử lý file: recorded_audio_HXiAFP6.webm
# Đang xử lý file: recorded_audio_HyzUz4I.webm
# Đang xử lý file: recorded_audio_hZg3FRY.webm
# Đang xử lý file: recorded_audio_hZrSXbD.webm
# Đang xử lý file: recorded_audio_hZTHwCT.webm
# Đang xử lý file: recorded_audio_i4R6L4V.webm
# Đang xử lý file: recorded_audio_i4XrWXa.webm
# Đang xử lý file: recorded_audio_i8e3BQH.webm
# Đang xử lý file: recorded_audio_i9Wd4Fs.webm
# Đang xử lý file: recorded_audio_iBoSMBm.webm
# Đang xử lý file: recorded_audio_ICXnhW2.webm
# Đang xử lý file: recorded_audio_IelcIZc.webm
# Đang xử lý file: recorded_audio_IFoO33T.webm
# Đang xử lý file: recorded_audio_Ifrouey.webm
# Đang xử lý file: recorded_audio_iIafeNu.webm
# Đang xử lý file: recorded_audio_iIwQWIN.webm
# Đang xử lý file: recorded_audio_ikglZkR.webm
# Đang xử lý file: recorded_audio_IKHrAGi.webm
# Đang xử lý file: recorded_audio_ikp7KEd.webm
# Đang xử lý file: recorded_audio_ikPkNv1.webm
# Đang xử lý file: recorded_audio_iKVg5rU.webm
# Đang xử lý file: recorded_audio_Il0ELtx.webm
# Đang xử lý file: recorded_audio_ImCpCJo.webm
# Đang xử lý file: recorded_audio_iN9lpc6.webm
# Đang xử lý file: recorded_audio_INahVoS.webm
# Đang xử lý file: recorded_audio_InfsDmN.webm
# Đang xử lý file: recorded_audio_inrn5at.webm
# Đang xử lý file: recorded_audio_InsuicG.webm
# Đang xử lý file: recorded_audio_IOlLL1O.webm
# Đang xử lý file: recorded_audio_iPbiQna.webm
# Đang xử lý file: recorded_audio_iqI0GbR.webm
# Đang xử lý file: recorded_audio_iQI3Ess.webm
# Đang xử lý file: recorded_audio_Iqie9Ru.webm
# Đang xử lý file: recorded_audio_iRsOr4B.webm
# Đang xử lý file: recorded_audio_IsR9kuI.webm
# Đang xử lý file: recorded_audio_ItBDShw.webm
# Đang xử lý file: recorded_audio_IthLA2p.webm
# Đang xử lý file: recorded_audio_iTPcsQe.webm
# Đang xử lý file: recorded_audio_iwMuZ78.webm
# Đang xử lý file: recorded_audio_J3J1far.webm
# Đang xử lý file: recorded_audio_j5g00Yw.webm
# Đang xử lý file: recorded_audio_J5QwGlc.webm
# Đang xử lý file: recorded_audio_j6mXio0.webm
# Đang xử lý file: recorded_audio_j8iAgk4.webm
# Đang xử lý file: recorded_audio_j8pIojf.webm
# Đang xử lý file: recorded_audio_j9ZupZR.webm
# Đang xử lý file: recorded_audio_jalDCLf.webm
# Đang xử lý file: recorded_audio_JbclwaZ.webm
# Đang xử lý file: recorded_audio_JbDykji.webm
# Đang xử lý file: recorded_audio_jbfswEc.webm
# Đang xử lý file: recorded_audio_jBSPPAn.webm
# Đang xử lý file: recorded_audio_Jbvxpuk.webm
# Đang xử lý file: recorded_audio_jcDo7ph.webm
# Đang xử lý file: recorded_audio_jcgTbVc.webm
# Đang xử lý file: recorded_audio_jCgXSRi.webm
# Đang xử lý file: recorded_audio_jCU2Rdz.webm
# Đang xử lý file: recorded_audio_JD2uqSU.webm
# Đang xử lý file: recorded_audio_jE4lIZP.webm
# Đang xử lý file: recorded_audio_je9UHWy.webm
# Đang xử lý file: recorded_audio_jECSqAy.webm
# Đang xử lý file: recorded_audio_JfR94Nj.webm
# Đang xử lý file: recorded_audio_JIv7bfX.webm
# Đang xử lý file: recorded_audio_jLNnOEi.webm
# Đang xử lý file: recorded_audio_jMJ7RZL.webm
# Đang xử lý file: recorded_audio_jnbeUmw.webm
# Đang xử lý file: recorded_audio_JnBqWhK.webm
# Đang xử lý file: recorded_audio_jo7HSmS.webm
# Đang xử lý file: recorded_audio_JoD4XvL.webm
# Đang xử lý file: recorded_audio_joTUld0.webm
# Đang xử lý file: recorded_audio_jP9mHtS.webm
# Đang xử lý file: recorded_audio_JPhb61X.webm
# Đang xử lý file: recorded_audio_jPikQsZ.webm
# Đang xử lý file: recorded_audio_JpVf84L.webm
# Đang xử lý file: recorded_audio_JPvzDSf.webm
# Đang xử lý file: recorded_audio_jq10Zac.webm
# Đang xử lý file: recorded_audio_jRLCTIZ.webm
# Đang xử lý file: recorded_audio_Jt4Ucga.webm
# Đang xử lý file: recorded_audio_JTmaWAM.webm
# Đang xử lý file: recorded_audio_jUpLFhV.webm
# Đang xử lý file: recorded_audio_JUYRots.webm
# Đang xử lý file: recorded_audio_jV9wsdD.webm
# Đang xử lý file: recorded_audio_JVCFmAC.webm
# Đang xử lý file: recorded_audio_JXwfTwv.webm
# Đang xử lý file: recorded_audio_JZvGLiu.webm
# Đang xử lý file: recorded_audio_k2hiVqD.webm
# Đang xử lý file: recorded_audio_k3pCycm.webm
# Đang xử lý file: recorded_audio_K4Ffpkk.webm
# Đang xử lý file: recorded_audio_K5b3gLx.webm
# Đang xử lý file: recorded_audio_k5ih6RH.webm
# Đang xử lý file: recorded_audio_K67pyN1.webm
# Đang xử lý file: recorded_audio_K7r9VPk.webm
# Đang xử lý file: recorded_audio_kanN8xc.webm
# Đang xử lý file: recorded_audio_KAwaRAe.webm
# Đang xử lý file: recorded_audio_kbKkmQo.webm
# Đang xử lý file: recorded_audio_kCAbSMq.webm
# Đang xử lý file: recorded_audio_kCcRVu5.webm
# Đang xử lý file: recorded_audio_kd0YJ2U.webm
# Đang xử lý file: recorded_audio_KewPm8b.webm
# Đang xử lý file: recorded_audio_kf1MW7T.webm
# Đang xử lý file: recorded_audio_kfRkevY.webm
# Đang xử lý file: recorded_audio_kik39tV.webm
# Đang xử lý file: recorded_audio_KJ0i2zh.webm
# Đang xử lý file: recorded_audio_KkeDrQa.webm
# Đang xử lý file: recorded_audio_klgLFic.webm
# Đang xử lý file: recorded_audio_KLmeEpb.webm
# Đang xử lý file: recorded_audio_kLmgbnl.webm
# Đang xử lý file: recorded_audio_Km1XSpN.webm
# Đang xử lý file: recorded_audio_kMbvCew.webm
# Đang xử lý file: recorded_audio_KNrlrN5.webm
# Đang xử lý file: recorded_audio_kooE5q8.webm
# Đang xử lý file: recorded_audio_koy6aUI.webm
# Đang xử lý file: recorded_audio_KPPDndU.webm
# Đang xử lý file: recorded_audio_kQX66wA.webm
# Đang xử lý file: recorded_audio_KrnQpSV.webm
# Đang xử lý file: recorded_audio_Krp93ic.webm
# Đang xử lý file: recorded_audio_kRRyq9M.webm
# Đang xử lý file: recorded_audio_ks35cg2.webm
# Đang xử lý file: recorded_audio_kSDSxZh.webm
# Đang xử lý file: recorded_audio_KSpcirP.webm
# Đang xử lý file: recorded_audio_KtD7sAV.webm
# Đang xử lý file: recorded_audio_kv5AG7O.webm
# Đang xử lý file: recorded_audio_KVIds61.webm
# Đang xử lý file: recorded_audio_Kwtnwq0.webm
# Đang xử lý file: recorded_audio_KYrW14i.webm
# Đang xử lý file: recorded_audio_kZ1ZfdW.webm
# Đang xử lý file: recorded_audio_KZDzXO8.webm
# Đang xử lý file: recorded_audio_Kzw46nZ.webm
# Đang xử lý file: recorded_audio_laI67s8.webm
# Đang xử lý file: recorded_audio_LAYZtF4.webm
# Đang xử lý file: recorded_audio_LB9hoKR.webm
# Đang xử lý file: recorded_audio_LBhe4Wq.webm
# Đang xử lý file: recorded_audio_LbmvR4M.webm
# Đang xử lý file: recorded_audio_lC55bvo.webm
# Đang xử lý file: recorded_audio_lcshNoJ.webm
# Đang xử lý file: recorded_audio_LCVbkO4.webm
# Đang xử lý file: recorded_audio_LdA0PjJ.webm
# Đang xử lý file: recorded_audio_LG0j806.webm
# Đang xử lý file: recorded_audio_lgdb7fI.webm
# Đang xử lý file: recorded_audio_LJJSkns.webm
# Đang xử lý file: recorded_audio_lJqP5jP.webm
# Đang xử lý file: recorded_audio_LkkDRvk.webm
# Đang xử lý file: recorded_audio_Ll04IFb.webm
# Đang xử lý file: recorded_audio_lLVQxcz.webm
# Đang xử lý file: recorded_audio_lOz466z.webm
# Đang xử lý file: recorded_audio_lr22uTr.webm
# Đang xử lý file: recorded_audio_Lrei2rH.webm
# Đang xử lý file: recorded_audio_Lrudssi.webm
# Đang xử lý file: recorded_audio_lS8TbiH.webm
# Đang xử lý file: recorded_audio_ltwMeWX.webm
# Đang xử lý file: recorded_audio_lu1aRag.webm
# Đang xử lý file: recorded_audio_LvrAyeO.webm
# Đang xử lý file: recorded_audio_LVX5qyP.webm
# Đang xử lý file: recorded_audio_lw7Fezd.webm
# Đang xử lý file: recorded_audio_LwLxOQk.webm
# Đang xử lý file: recorded_audio_lx0zYBq.webm
# Đang xử lý file: recorded_audio_lxFUosZ.webm
# Đang xử lý file: recorded_audio_ly5qSzL.webm
# Đang xử lý file: recorded_audio_ly77r84.webm
# Đang xử lý file: recorded_audio_LylE51q.webm
# Đang xử lý file: recorded_audio_lZcW4z7.webm
# Đang xử lý file: recorded_audio_LZooRX5.webm
# Đang xử lý file: recorded_audio_M0GQbbV.webm
# Đang xử lý file: recorded_audio_m4UVnRO.webm
# Đang xử lý file: recorded_audio_m54wo18.webm
# Đang xử lý file: recorded_audio_M6Mi56h.webm
# Đang xử lý file: recorded_audio_m8enD8D.webm
# Đang xử lý file: recorded_audio_mAXdfMX.webm
# Đang xử lý file: recorded_audio_MbwY20J.webm
# Đang xử lý file: recorded_audio_ME19gtx.webm
# Đang xử lý file: recorded_audio_meAk8VX.webm
# Đang xử lý file: recorded_audio_MfLCkUD.webm
# Đang xử lý file: recorded_audio_mfYlIiG.webm
# Đang xử lý file: recorded_audio_mG2sgaP.webm
# Đang xử lý file: recorded_audio_mGfrYgW.webm
# Đang xử lý file: recorded_audio_mgpOzq3.webm
# Đang xử lý file: recorded_audio_MhBg4M3.webm
# Đang xử lý file: recorded_audio_Mhiuz8D.webm
# Đang xử lý file: recorded_audio_miToQCi.webm
# Đang xử lý file: recorded_audio_mj0PfII.webm
# Đang xử lý file: recorded_audio_mJA8v4l.webm
# Đang xử lý file: recorded_audio_mjDIIna.webm
# Đang xử lý file: recorded_audio_mlthxWO.webm
# Đang xử lý file: recorded_audio_mM3uJ0d.webm
# Đang xử lý file: recorded_audio_mn1tydd.webm
# Đang xử lý file: recorded_audio_mNQTB2g.webm
# Đang xử lý file: recorded_audio_MRMlFrW.webm
# Đang xử lý file: recorded_audio_Mts9COR.webm
# Đang xử lý file: recorded_audio_mv0wfDf.webm
# Đang xử lý file: recorded_audio_mvbPF9a.webm
# Đang xử lý file: recorded_audio_MymgY6h.webm
# Đang xử lý file: recorded_audio_N06MaJS.webm
# Đang xử lý file: recorded_audio_n0q74wd.webm
# Đang xử lý file: recorded_audio_N3fqXis.webm
# Đang xử lý file: recorded_audio_N53WssB.webm
# Đang xử lý file: recorded_audio_n5YfT5l.webm
# Đang xử lý file: recorded_audio_NajtwfZ.webm
# Đang xử lý file: recorded_audio_naVVq6l.webm
# Đang xử lý file: recorded_audio_NbKX6JS.webm
# Đang xử lý file: recorded_audio_nbxl5YE.webm
# Đang xử lý file: recorded_audio_nCK27Z5.webm
# Đang xử lý file: recorded_audio_NCYj3t3.webm
# Đang xử lý file: recorded_audio_NDN6Tmo.webm
# Đang xử lý file: recorded_audio_Ne32pW4.webm
# Đang xử lý file: recorded_audio_NEAL3qm.webm
# Đang xử lý file: recorded_audio_Neewco9.webm
# Đang xử lý file: recorded_audio_NI0arZf.webm
# Đang xử lý file: recorded_audio_NiFbKKy.webm
# Đang xử lý file: recorded_audio_njJhElz.webm
# Đang xử lý file: recorded_audio_njumxKY.webm
# Đang xử lý file: recorded_audio_nK3hZsb.webm
# Đang xử lý file: recorded_audio_NKtu2TB.webm
# Đang xử lý file: recorded_audio_Nlh0DQM.webm
# Đang xử lý file: recorded_audio_Nmg2Ils.webm
# Đang xử lý file: recorded_audio_NmsZl8w.webm
# Đang xử lý file: recorded_audio_NNCkbHT.webm
# Đang xử lý file: recorded_audio_nnKEZHR.webm
# Đang xử lý file: recorded_audio_NpA1Xjy.webm
# Đang xử lý file: recorded_audio_nPCnhWa.webm
# Đang xử lý file: recorded_audio_nPEuAAq.webm
# Đang xử lý file: recorded_audio_NpmegxE.webm
# Đang xử lý file: recorded_audio_nR1VF0S.webm
# Đang xử lý file: recorded_audio_NrJKUfM.webm
# Đang xử lý file: recorded_audio_NRtuPVT.webm
# Đang xử lý file: recorded_audio_nSnEHQj.webm
# Đang xử lý file: recorded_audio_ntvSYLZ.webm
# Đang xử lý file: recorded_audio_NVGC6DE.webm
# Đang xử lý file: recorded_audio_nX535py.webm
# Đang xử lý file: recorded_audio_NyMN1w6.webm
# Đang xử lý file: recorded_audio_nyYL4HS.webm
# Đang xử lý file: recorded_audio_nZB5ujA.webm
# Đang xử lý file: recorded_audio_NzhIwd2.webm
# Đang xử lý file: recorded_audio_o06YaOw.webm
# Đang xử lý file: recorded_audio_O0kWKhg.webm
# Đang xử lý file: recorded_audio_o1hNZpl.webm
# Đang xử lý file: recorded_audio_O3HRBsY.webm
# Đang xử lý file: recorded_audio_o4364xW.webm
# Đang xử lý file: recorded_audio_o4jFM9e.webm
# Đang xử lý file: recorded_audio_O5sBDcO.webm
# Đang xử lý file: recorded_audio_O5U0Rmx.webm
# Đang xử lý file: recorded_audio_O7bIOhm.webm
# Đang xử lý file: recorded_audio_o8v8xzu.webm
# Đang xử lý file: recorded_audio_o9xOF45.webm
# Đang xử lý file: recorded_audio_OAlPhwz.webm
# Đang xử lý file: recorded_audio_oB8RqHv.webm
# Đang xử lý file: recorded_audio_OeaXVPR.webm
# Đang xử lý file: recorded_audio_Oeor54V.webm
# Đang xử lý file: recorded_audio_OG5x7YX.webm
# Đang xử lý file: recorded_audio_oGl6q2Q.webm
# Đang xử lý file: recorded_audio_oGPqWNq.webm
# Đang xử lý file: recorded_audio_ohe0Ez6.webm
# Đang xử lý file: recorded_audio_ohfGcS9.webm
# Đang xử lý file: recorded_audio_ohknBLU.webm
# Đang xử lý file: recorded_audio_oK5dTDZ.webm
# Đang xử lý file: recorded_audio_OKBjqc2.webm
# Đang xử lý file: recorded_audio_OKCThLO.webm
# Đang xử lý file: recorded_audio_OKMhMVU.webm
# Đang xử lý file: recorded_audio_omc9yGQ.webm
# Đang xử lý file: recorded_audio_OMf8CEL.webm
# Đang xử lý file: recorded_audio_ONH9BHa.webm
# Đang xử lý file: recorded_audio_onxS5Sb.webm
# Đang xử lý file: recorded_audio_OoC7nKT.webm
# Đang xử lý file: recorded_audio_OoMMQa1.webm
# Đang xử lý file: recorded_audio_opag094.webm
# Đang xử lý file: recorded_audio_opWXPFw.webm
# Đang xử lý file: recorded_audio_OSBmuuf.webm
# Đang xử lý file: recorded_audio_osSBHAA.webm
# Đang xử lý file: recorded_audio_Osyhsle.webm
# Đang xử lý file: recorded_audio_Ot3mcLJ.webm
# Đang xử lý file: recorded_audio_OtXtoN5.webm
# Đang xử lý file: recorded_audio_OUgkVLj.webm
# Đang xử lý file: recorded_audio_OVUAtxD.webm
# Đang xử lý file: recorded_audio_OX7rIn1.webm
# Đang xử lý file: recorded_audio_Oy8ANqo.webm
# Đang xử lý file: recorded_audio_oyeCBDW.webm
# Đang xử lý file: recorded_audio_oYSsuh8.webm
# Đang xử lý file: recorded_audio_OYxoqti.webm
# Đang xử lý file: recorded_audio_OzUEoUs.webm
# Đang xử lý file: recorded_audio_p0AqG4K.webm
# Đang xử lý file: recorded_audio_p0WuSlc.webm
# Đang xử lý file: recorded_audio_p0x7X7T.webm
# Đang xử lý file: recorded_audio_P18Xs8n.webm
# Đang xử lý file: recorded_audio_P690l70.webm
# Đang xử lý file: recorded_audio_P7YJdYT.webm
# Đang xử lý file: recorded_audio_PatWW7X.webm
# Đang xử lý file: recorded_audio_pBb29Ay.webm
# Đang xử lý file: recorded_audio_pBqK8xN.webm
# Đang xử lý file: recorded_audio_pcFiv3B.webm
# Đang xử lý file: recorded_audio_pcuFYLo.webm
# Đang xử lý file: recorded_audio_Pe3Ayrh.webm
# Đang xử lý file: recorded_audio_peBd5Bx.webm
# Đang xử lý file: recorded_audio_PEcKjUe.webm
# Đang xử lý file: recorded_audio_pHms5lI.webm
# Đang xử lý file: recorded_audio_PIRGBbv.webm
# Đang xử lý file: recorded_audio_pJ5RMNe.webm
# Đang xử lý file: recorded_audio_pJguL0e.webm
# Đang xử lý file: recorded_audio_pKBsD7z.webm
# Đang xử lý file: recorded_audio_Pl8ipD9.webm
# Đang xử lý file: recorded_audio_plxpSnh.webm
# Đang xử lý file: recorded_audio_pMzDf5v.webm
# Đang xử lý file: recorded_audio_pn1CRXN.webm
# Đang xử lý file: recorded_audio_PP1YrwL.webm
# Đang xử lý file: recorded_audio_PpLi2R5.webm
# Đang xử lý file: recorded_audio_pqr9AKM.webm
# Đang xử lý file: recorded_audio_PrNiJLo.webm
# Đang xử lý file: recorded_audio_PsiLm8R.webm
# Đang xử lý file: recorded_audio_puaChuW.webm
# Đang xử lý file: recorded_audio_pX8WOWJ.webm
# Đang xử lý file: recorded_audio_pxbIeP7.webm
# Đang xử lý file: recorded_audio_PXNjmrh.webm
# Đang xử lý file: recorded_audio_pYKlCHD.webm
# Đang xử lý file: recorded_audio_pZRd04b.webm
# Đang xử lý file: recorded_audio_Q0CCiET.webm
# Đang xử lý file: recorded_audio_Q1Gr0Jz.webm
# Đang xử lý file: recorded_audio_q3SZdCQ.webm
# Đang xử lý file: recorded_audio_q4Wah2A.webm
# Đang xử lý file: recorded_audio_q8D0vrx.webm
# Đang xử lý file: recorded_audio_q94Ct39.webm
# Đang xử lý file: recorded_audio_Q9zC93k.webm
# Đang xử lý file: recorded_audio_qAyuIM6.webm
# Đang xử lý file: recorded_audio_Qb4VBMl.webm
# Đang xử lý file: recorded_audio_QBCau5m.webm
# Đang xử lý file: recorded_audio_QC8uc0G.webm
# Đang xử lý file: recorded_audio_qd88htb.webm
# Đang xử lý file: recorded_audio_QDGMqEG.webm
# Đang xử lý file: recorded_audio_QDjMoIJ.webm
# Đang xử lý file: recorded_audio_qEEhlex.webm
# Đang xử lý file: recorded_audio_QeemCpY.webm
# Đang xử lý file: recorded_audio_qELhSek.webm
# Đang xử lý file: recorded_audio_Qfb15uP.webm
# Đang xử lý file: recorded_audio_qFf6o1H.webm
# Đang xử lý file: recorded_audio_qFJEweA.webm
# Đang xử lý file: recorded_audio_qfuBXnI.webm
# Đang xử lý file: recorded_audio_QhGvJGL.webm
# Đang xử lý file: recorded_audio_qieTcyg.webm
# Đang xử lý file: recorded_audio_QIFYZDI.webm
# Đang xử lý file: recorded_audio_QJBoQsG.webm
# Đang xử lý file: recorded_audio_qjTK2wv.webm
# Đang xử lý file: recorded_audio_qKGEFFH.webm
# Đang xử lý file: recorded_audio_qKr0SVn.webm
# Đang xử lý file: recorded_audio_qkVivqd.webm
# Đang xử lý file: recorded_audio_qL4JVHj.webm
# Đang xử lý file: recorded_audio_qlFLh26.webm
# Đang xử lý file: recorded_audio_qMpjT9A.webm
# Đang xử lý file: recorded_audio_Qo1OPnp.webm
# Đang xử lý file: recorded_audio_QOMhtLJ.webm
# Đang xử lý file: recorded_audio_QpcXkXs.webm
# Đang xử lý file: recorded_audio_qQRuJvK.webm
# Đang xử lý file: recorded_audio_qSWtEF5.webm
# Đang xử lý file: recorded_audio_QthCONQ.webm
# Đang xử lý file: recorded_audio_qtvRDK4.webm
# Đang xử lý file: recorded_audio_QWGviBS.webm
# Đang xử lý file: recorded_audio_QwWBamI.webm
# Đang xử lý file: recorded_audio_QYwhW0v.webm
# Đang xử lý file: recorded_audio_qZY5d9C.webm
# Đang xử lý file: recorded_audio_R1b2LHp.webm
# Đang xử lý file: recorded_audio_r2kkK1M.webm
# Đang xử lý file: recorded_audio_r2shSgF.webm
# Đang xử lý file: recorded_audio_R35s78l.webm
# Đang xử lý file: recorded_audio_R4tW3S4.webm
# Đang xử lý file: recorded_audio_R6T2Z25.webm
# Đang xử lý file: recorded_audio_R7w4Gti.webm
# Đang xử lý file: recorded_audio_R9Duktf.webm
# Đang xử lý file: recorded_audio_RanVlvV.webm
# Đang xử lý file: recorded_audio_RasdZ7f.webm
# Đang xử lý file: recorded_audio_RdxnI19.webm
# Đang xử lý file: recorded_audio_RdzPlQt.webm
# Đang xử lý file: recorded_audio_ReBGM47.webm
# Đang xử lý file: recorded_audio_ReYyexr.webm
# Đang xử lý file: recorded_audio_RF6OuQ4.webm
# Đang xử lý file: recorded_audio_rFCCrwX.webm
# Đang xử lý file: recorded_audio_rFgbkwP.webm
# Đang xử lý file: recorded_audio_rGGFiCJ.webm
# Đang xử lý file: recorded_audio_rguPlLs.webm
# Đang xử lý file: recorded_audio_rhNQpOp.webm
# Đang xử lý file: recorded_audio_ri8ik62.webm
# Đang xử lý file: recorded_audio_riq3c4b.webm
# Đang xử lý file: recorded_audio_rjjF7Xa.webm
# Đang xử lý file: recorded_audio_rJNgmAC.webm
# Đang xử lý file: recorded_audio_rJwe8tq.webm
# Đang xử lý file: recorded_audio_rJxYBwU.webm
# Đang xử lý file: recorded_audio_rKyBDi5.webm
# Đang xử lý file: recorded_audio_rlBCvLM.webm
# Đang xử lý file: recorded_audio_rMF5bCZ.webm
# Đang xử lý file: recorded_audio_RMFS8QW.webm
# Đang xử lý file: recorded_audio_rmIFSfB.webm
# Đang xử lý file: recorded_audio_RniqALr.webm
# Đang xử lý file: recorded_audio_rNWPz7J.webm
# Đang xử lý file: recorded_audio_ro2dOpZ.webm
# Đang xử lý file: recorded_audio_ROSR4KW.webm
# Đang xử lý file: recorded_audio_RpgaA2p.webm
# Đang xử lý file: recorded_audio_RpsB2D1.webm
# Đang xử lý file: recorded_audio_rpXLLji.webm
# Đang xử lý file: recorded_audio_rRMsNHI.webm
# Đang xử lý file: recorded_audio_RSiWUvu.webm
# Đang xử lý file: recorded_audio_RtCNgV7.webm
# Đang xử lý file: recorded_audio_Rv3ZQYG.webm
# Đang xử lý file: recorded_audio_RVZmdsi.webm
# Đang xử lý file: recorded_audio_rwaOHTp.webm
# Đang xử lý file: recorded_audio_RwFFcYb.webm
# Đang xử lý file: recorded_audio_rx6yZeQ.webm
# Đang xử lý file: recorded_audio_RxEsJkZ.webm
# Đang xử lý file: recorded_audio_rY3Cehz.webm
# Đang xử lý file: recorded_audio_s3yInjU.webm
# Đang xử lý file: recorded_audio_S5ePiqu.webm
# Đang xử lý file: recorded_audio_SA8T0fL.webm
# Đang xử lý file: recorded_audio_sAFnMYX.webm
# Đang xử lý file: recorded_audio_sb5ZruA.webm
# Đang xử lý file: recorded_audio_SbmKwNC.webm
# Đang xử lý file: recorded_audio_se8U3dW.webm
# Đang xử lý file: recorded_audio_SezkNnL.webm
# Đang xử lý file: recorded_audio_SffXIVy.webm
# Đang xử lý file: recorded_audio_SFiwyqY.webm
# Đang xử lý file: recorded_audio_sFwkOlF.webm
# Đang xử lý file: recorded_audio_shTlecP.webm
# Đang xử lý file: recorded_audio_sjK1D8m.webm
# Đang xử lý file: recorded_audio_SJZAD7M.webm
# Đang xử lý file: recorded_audio_skeLStj.webm
# Đang xử lý file: recorded_audio_sMi3N5y.webm
# Đang xử lý file: recorded_audio_SMjeiUS.webm
# Đang xử lý file: recorded_audio_smsRuz7.webm
# Đang xử lý file: recorded_audio_snjTSfD.webm
# Đang xử lý file: recorded_audio_SnNZ2eY.webm
# Đang xử lý file: recorded_audio_SNwhysQ.webm
# Đang xử lý file: recorded_audio_spY1y48.webm
# Đang xử lý file: recorded_audio_SQHzfnd.webm
# Đang xử lý file: recorded_audio_sR15M45.webm
# Đang xử lý file: recorded_audio_Ss4hO7q.webm
# Đang xử lý file: recorded_audio_SSY6oNR.webm
# Đang xử lý file: recorded_audio_SUnYB9W.webm
# Đang xử lý file: recorded_audio_Sv7NjBN.webm
# Đang xử lý file: recorded_audio_SW8Ub1i.webm
# Đang xử lý file: recorded_audio_sWpLH0A.webm
# Đang xử lý file: recorded_audio_sYCm4ry.webm
# Đang xử lý file: recorded_audio_sYxbAGD.webm
# Đang xử lý file: recorded_audio_SzQqP30.webm
# Đang xử lý file: recorded_audio_T0dbmuR.webm
# Đang xử lý file: recorded_audio_t1DytfA.webm
# Đang xử lý file: recorded_audio_t2jQjvR.webm
# Đang xử lý file: recorded_audio_t3lnOha.webm
# Đang xử lý file: recorded_audio_T42eXGN.webm
# Đang xử lý file: recorded_audio_t5PeRVu.webm
# Đang xử lý file: recorded_audio_t6Tbrre.webm
# Đang xử lý file: recorded_audio_t7bDMzY.webm
# Đang xử lý file: recorded_audio_TAyZ6JZ.webm
# Đang xử lý file: recorded_audio_TBdgipG.webm
# Đang xử lý file: recorded_audio_TDxhJNu.webm
# Đang xử lý file: recorded_audio_TEcMz6f.webm
# Đang xử lý file: recorded_audio_TEOG37Y.webm
# Đang xử lý file: recorded_audio_tf7fvWP.webm
# Đang xử lý file: recorded_audio_tHebuIU.webm
# Đang xử lý file: recorded_audio_TithtlC.webm
# Đang xử lý file: recorded_audio_tKJvqya.webm
# Đang xử lý file: recorded_audio_tLgBEPR.webm
# Đang xử lý file: recorded_audio_TqfWcm6.webm
# Đang xử lý file: recorded_audio_tqWIEki.webm
# Đang xử lý file: recorded_audio_tr7BJnm.webm
# Đang xử lý file: recorded_audio_TsbQhdf.webm
# Đang xử lý file: recorded_audio_tT8IOJQ.webm
# Đang xử lý file: recorded_audio_tT8JKpi.webm
# Đang xử lý file: recorded_audio_Ttj3Kdc.webm
# Đang xử lý file: recorded_audio_TTKbqLs.webm
# Đang xử lý file: recorded_audio_Tvpwv0o.webm
# Đang xử lý file: recorded_audio_TW2Gc6r.webm
# Đang xử lý file: recorded_audio_TWd4gyL.webm
# Đang xử lý file: recorded_audio_TXLHXZj.webm
# Đang xử lý file: recorded_audio_Txs1dR4.webm
# Đang xử lý file: recorded_audio_Ty4W1pu.webm
# Đang xử lý file: recorded_audio_Tz8nfuk.webm
# Đang xử lý file: recorded_audio_Tz9ysnA.webm
# Đang xử lý file: recorded_audio_u0KWuQM.webm
# Đang xử lý file: recorded_audio_u2xubGw.webm
# Đang xử lý file: recorded_audio_u5Nvy54.webm
# Đang xử lý file: recorded_audio_u6wYnL4.webm
# Đang xử lý file: recorded_audio_uberf7h.webm
# Đang xử lý file: recorded_audio_UCuYMb6.webm
# Đang xử lý file: recorded_audio_UDERrZ4.webm
# Đang xử lý file: recorded_audio_UdHJK8T.webm
# Đang xử lý file: recorded_audio_UfB4RXd.webm
# Đang xử lý file: recorded_audio_UfjXOIf.webm
# Đang xử lý file: recorded_audio_ujlraYC.webm
# Đang xử lý file: recorded_audio_UJufLyM.webm
# Đang xử lý file: recorded_audio_UJwfLcW.webm
# Đang xử lý file: recorded_audio_Uk46fgo.webm
# Đang xử lý file: recorded_audio_uKEc02K.webm
# Đang xử lý file: recorded_audio_uKlgiXa.webm
# Đang xử lý file: recorded_audio_uKtp0YZ.webm
# Đang xử lý file: recorded_audio_ULTeVXH.webm
# Đang xử lý file: recorded_audio_uNvAwrl.webm
# Đang xử lý file: recorded_audio_uo9trlv.webm
# Đang xử lý file: recorded_audio_UOFTagZ.webm
# Đang xử lý file: recorded_audio_UPDFTR2.webm
# Đang xử lý file: recorded_audio_UqzfT0q.webm
# Đang xử lý file: recorded_audio_usgHd6v.webm
# Đang xử lý file: recorded_audio_UtfzVkq.webm
# Đang xử lý file: recorded_audio_uWyWoVO.webm
# Đang xử lý file: recorded_audio_ux98Sz3.webm
# Đang xử lý file: recorded_audio_uXbD2lt.webm
# Đang xử lý file: recorded_audio_uXQ1TKp.webm
# Đang xử lý file: recorded_audio_uyEkRAw.webm
# Đang xử lý file: recorded_audio_UYQP2Jn.webm
# Đang xử lý file: recorded_audio_uZE3dKD.webm
# Đang xử lý file: recorded_audio_V0bOGla.webm
# Đang xử lý file: recorded_audio_v2Sscx0.webm
# Đang xử lý file: recorded_audio_v420niy.webm
# Đang xử lý file: recorded_audio_V4MXaGo.webm
# Đang xử lý file: recorded_audio_v6ameNd.webm
# Đang xử lý file: recorded_audio_v6qwjD3.webm
# Đang xử lý file: recorded_audio_V6zH0Zh.webm
# Đang xử lý file: recorded_audio_v8Cauqs.webm
# Đang xử lý file: recorded_audio_v8I9KMp.webm
# Đang xử lý file: recorded_audio_VD1lFmL.webm
# Đang xử lý file: recorded_audio_VdZQUAd.webm
# Đang xử lý file: recorded_audio_VebHIxd.webm
# Đang xử lý file: recorded_audio_vF0i1eF.webm
# Đang xử lý file: recorded_audio_vgGDmpj.webm
# Đang xử lý file: recorded_audio_VGp1NFy.webm
# Đang xử lý file: recorded_audio_viKkUCZ.webm
# Đang xử lý file: recorded_audio_vJLs0Zs.webm
# Đang xử lý file: recorded_audio_vjtG9FC.webm
# Đang xử lý file: recorded_audio_vkHyyTm.webm
# Đang xử lý file: recorded_audio_VkXIhIM.webm
# Đang xử lý file: recorded_audio_vLFYvqO.webm
# Đang xử lý file: recorded_audio_vmvzVZk.webm
# Đang xử lý file: recorded_audio_vNT3hty.webm
# Đang xử lý file: recorded_audio_VP1AW1l.webm
# Đang xử lý file: recorded_audio_vPRtT8a.webm
# Đang xử lý file: recorded_audio_vPYOeYJ.webm
# Đang xử lý file: recorded_audio_VqRGmGO.webm
# Đang xử lý file: recorded_audio_vrnWmLG.webm
# Đang xử lý file: recorded_audio_vro9eoT.webm
# Đang xử lý file: recorded_audio_vSLKerL.webm
# Đang xử lý file: recorded_audio_Vu7t50Y.webm
# Đang xử lý file: recorded_audio_vwKjOQf.webm
# Đang xử lý file: recorded_audio_vWMZjZG.webm
# Đang xử lý file: recorded_audio_vWnrtaJ.webm
# Đang xử lý file: recorded_audio_vX14sQp.webm
# Đang xử lý file: recorded_audio_W1mXUYw.webm
# Đang xử lý file: recorded_audio_w1qwCzb.webm
# Đang xử lý file: recorded_audio_W46PVUO.webm
# Đang xử lý file: recorded_audio_W4Q77Qg.webm
# Đang xử lý file: recorded_audio_W5EXMUn.webm
# Đang xử lý file: recorded_audio_w5IGBKb.webm
# Đang xử lý file: recorded_audio_w5RdQag.webm
# Đang xử lý file: recorded_audio_W6BOSpw.webm
# Đang xử lý file: recorded_audio_w6Hs0tq.webm
# Đang xử lý file: recorded_audio_W8eUFcY.webm
# Đang xử lý file: recorded_audio_w8w96Dj.webm
# Đang xử lý file: recorded_audio_WAVdCYp.webm
# Đang xử lý file: recorded_audio_WbLLRP0.webm
# Đang xử lý file: recorded_audio_wbmKWUG.webm
# Đang xử lý file: recorded_audio_wBtyCGw.webm
# Đang xử lý file: recorded_audio_wC6dAsG.webm
# Đang xử lý file: recorded_audio_WDFPLdq.webm
# ...
# Chuyển đổi thành công: recorded_audio_u5Nvy54.webm -> recorded_audio_u5Nvy54.wav
# Chuyển đổi thành công: recorded_audio_u6wYnL4.webm -> recorded_audio_u6wYnL4.wav
# Chuyển đổi thành công: recorded_audio_uberf7h.webm -> recorded_audio_uberf7h.wav
# Chuyển đổi thành công: recorded_audio_UCuYMb6.webm -> recorded_audio_UCuYMb6.wav
# Chuyển đổi thành công: recorded_audio_UDERrZ4.webm -> recorded_audio_UDERrZ4.wav
# Chuyển đổi thành công: recorded_audio_UdHJK8T.webm -> recorded_audio_UdHJK8T.wav
# Chuyển đổi thành công: recorded_audio_UfB4RXd.webm -> recorded_audio_UfB4RXd.wav
# Chuyển đổi thành công: recorded_audio_UfjXOIf.webm -> recorded_audio_UfjXOIf.wav
# Chuyển đổi thành công: recorded_audio_ujlraYC.webm -> recorded_audio_ujlraYC.wav
# Chuyển đổi thành công: recorded_audio_UJufLyM.webm -> recorded_audio_UJufLyM.wav
# Chuyển đổi thành công: recorded_audio_UJwfLcW.webm -> recorded_audio_UJwfLcW.wav
# Chuyển đổi thành công: recorded_audio_Uk46fgo.webm -> recorded_audio_Uk46fgo.wav
# Chuyển đổi thành công: recorded_audio_uKEc02K.webm -> recorded_audio_uKEc02K.wav
# Chuyển đổi thành công: recorded_audio_uKlgiXa.webm -> recorded_audio_uKlgiXa.wav
# Chuyển đổi thành công: recorded_audio_uKtp0YZ.webm -> recorded_audio_uKtp0YZ.wav
# Chuyển đổi thành công: recorded_audio_ULTeVXH.webm -> recorded_audio_ULTeVXH.wav
# Chuyển đổi thành công: recorded_audio_uNvAwrl.webm -> recorded_audio_uNvAwrl.wav
# Chuyển đổi thành công: recorded_audio_uo9trlv.webm -> recorded_audio_uo9trlv.wav
# Chuyển đổi thành công: recorded_audio_UOFTagZ.webm -> recorded_audio_UOFTagZ.wav
# Chuyển đổi thành công: recorded_audio_UPDFTR2.webm -> recorded_audio_UPDFTR2.wav
# Chuyển đổi thành công: recorded_audio_UqzfT0q.webm -> recorded_audio_UqzfT0q.wav
# Chuyển đổi thành công: recorded_audio_usgHd6v.webm -> recorded_audio_usgHd6v.wav
# Chuyển đổi thành công: recorded_audio_UtfzVkq.webm -> recorded_audio_UtfzVkq.wav
# Chuyển đổi thành công: recorded_audio_uWyWoVO.webm -> recorded_audio_uWyWoVO.wav
# Chuyển đổi thành công: recorded_audio_ux98Sz3.webm -> recorded_audio_ux98Sz3.wav
# Chuyển đổi thành công: recorded_audio_uXbD2lt.webm -> recorded_audio_uXbD2lt.wav
# Chuyển đổi thành công: recorded_audio_uXQ1TKp.webm -> recorded_audio_uXQ1TKp.wav
# Chuyển đổi thành công: recorded_audio_uyEkRAw.webm -> recorded_audio_uyEkRAw.wav
# Chuyển đổi thành công: recorded_audio_UYQP2Jn.webm -> recorded_audio_UYQP2Jn.wav
# Chuyển đổi thành công: recorded_audio_uZE3dKD.webm -> recorded_audio_uZE3dKD.wav
# Chuyển đổi thành công: recorded_audio_V0bOGla.webm -> recorded_audio_V0bOGla.wav
# Chuyển đổi thành công: recorded_audio_v2Sscx0.webm -> recorded_audio_v2Sscx0.wav
# Chuyển đổi thành công: recorded_audio_v420niy.webm -> recorded_audio_v420niy.wav
# Chuyển đổi thành công: recorded_audio_V4MXaGo.webm -> recorded_audio_V4MXaGo.wav
# Chuyển đổi thành công: recorded_audio_v6ameNd.webm -> recorded_audio_v6ameNd.wav
# Chuyển đổi thành công: recorded_audio_v6qwjD3.webm -> recorded_audio_v6qwjD3.wav
# Chuyển đổi thành công: recorded_audio_V6zH0Zh.webm -> recorded_audio_V6zH0Zh.wav
# Chuyển đổi thành công: recorded_audio_v8Cauqs.webm -> recorded_audio_v8Cauqs.wav
# Chuyển đổi thành công: recorded_audio_v8I9KMp.webm -> recorded_audio_v8I9KMp.wav
# Chuyển đổi thành công: recorded_audio_VD1lFmL.webm -> recorded_audio_VD1lFmL.wav
# Chuyển đổi thành công: recorded_audio_VdZQUAd.webm -> recorded_audio_VdZQUAd.wav
# Chuyển đổi thành công: recorded_audio_VebHIxd.webm -> recorded_audio_VebHIxd.wav
# Chuyển đổi thành công: recorded_audio_vF0i1eF.webm -> recorded_audio_vF0i1eF.wav
# Chuyển đổi thành công: recorded_audio_vgGDmpj.webm -> recorded_audio_vgGDmpj.wav
# Chuyển đổi thành công: recorded_audio_VGp1NFy.webm -> recorded_audio_VGp1NFy.wav
# Chuyển đổi thành công: recorded_audio_viKkUCZ.webm -> recorded_audio_viKkUCZ.wav
# Chuyển đổi thành công: recorded_audio_vJLs0Zs.webm -> recorded_audio_vJLs0Zs.wav
# Chuyển đổi thành công: recorded_audio_vjtG9FC.webm -> recorded_audio_vjtG9FC.wav
# Chuyển đổi thành công: recorded_audio_vkHyyTm.webm -> recorded_audio_vkHyyTm.wav
# Chuyển đổi thành công: recorded_audio_VkXIhIM.webm -> recorded_audio_VkXIhIM.wav
# Chuyển đổi thành công: recorded_audio_vLFYvqO.webm -> recorded_audio_vLFYvqO.wav
# Chuyển đổi thành công: recorded_audio_vmvzVZk.webm -> recorded_audio_vmvzVZk.wav
# Chuyển đổi thành công: recorded_audio_vNT3hty.webm -> recorded_audio_vNT3hty.wav
# Chuyển đổi thành công: recorded_audio_VP1AW1l.webm -> recorded_audio_VP1AW1l.wav
# Chuyển đổi thành công: recorded_audio_vPRtT8a.webm -> recorded_audio_vPRtT8a.wav
# Chuyển đổi thành công: recorded_audio_vPYOeYJ.webm -> recorded_audio_vPYOeYJ.wav
# Chuyển đổi thành công: recorded_audio_VqRGmGO.webm -> recorded_audio_VqRGmGO.wav
# Chuyển đổi thành công: recorded_audio_vrnWmLG.webm -> recorded_audio_vrnWmLG.wav
# Chuyển đổi thành công: recorded_audio_vro9eoT.webm -> recorded_audio_vro9eoT.wav
# Chuyển đổi thành công: recorded_audio_vSLKerL.webm -> recorded_audio_vSLKerL.wav
# Chuyển đổi thành công: recorded_audio_Vu7t50Y.webm -> recorded_audio_Vu7t50Y.wav
# Chuyển đổi thành công: recorded_audio_vwKjOQf.webm -> recorded_audio_vwKjOQf.wav
# Chuyển đổi thành công: recorded_audio_vWMZjZG.webm -> recorded_audio_vWMZjZG.wav
# Chuyển đổi thành công: recorded_audio_vWnrtaJ.webm -> recorded_audio_vWnrtaJ.wav
# Chuyển đổi thành công: recorded_audio_vX14sQp.webm -> recorded_audio_vX14sQp.wav
# Chuyển đổi thành công: recorded_audio_W1mXUYw.webm -> recorded_audio_W1mXUYw.wav
# Chuyển đổi thành công: recorded_audio_w1qwCzb.webm -> recorded_audio_w1qwCzb.wav
# Chuyển đổi thành công: recorded_audio_W46PVUO.webm -> recorded_audio_W46PVUO.wav
# Chuyển đổi thành công: recorded_audio_W4Q77Qg.webm -> recorded_audio_W4Q77Qg.wav
# Chuyển đổi thành công: recorded_audio_W5EXMUn.webm -> recorded_audio_W5EXMUn.wav
# Chuyển đổi thành công: recorded_audio_w5IGBKb.webm -> recorded_audio_w5IGBKb.wav
# Chuyển đổi thành công: recorded_audio_w5RdQag.webm -> recorded_audio_w5RdQag.wav
# Chuyển đổi thành công: recorded_audio_W6BOSpw.webm -> recorded_audio_W6BOSpw.wav
# Chuyển đổi thành công: recorded_audio_w6Hs0tq.webm -> recorded_audio_w6Hs0tq.wav
# Chuyển đổi thành công: recorded_audio_W8eUFcY.webm -> recorded_audio_W8eUFcY.wav
# Chuyển đổi thành công: recorded_audio_w8w96Dj.webm -> recorded_audio_w8w96Dj.wav
# Chuyển đổi thành công: recorded_audio_WAVdCYp.webm -> recorded_audio_WAVdCYp.wav
# Chuyển đổi thành công: recorded_audio_WbLLRP0.webm -> recorded_audio_WbLLRP0.wav
# Chuyển đổi thành công: recorded_audio_wbmKWUG.webm -> recorded_audio_wbmKWUG.wav
# Chuyển đổi thành công: recorded_audio_wBtyCGw.webm -> recorded_audio_wBtyCGw.wav
# Chuyển đổi thành công: recorded_audio_wC6dAsG.webm -> recorded_audio_wC6dAsG.wav
# Chuyển đổi thành công: recorded_audio_WDFPLdq.webm -> recorded_audio_WDFPLdq.wav
# Chuyển đổi thành công: recorded_audio_wDkyTBD.webm -> recorded_audio_wDkyTBD.wav
# Chuyển đổi thành công: recorded_audio_wdm2Rvd.webm -> recorded_audio_wdm2Rvd.wav
# Chuyển đổi thành công: recorded_audio_WEmFcMt.webm -> recorded_audio_WEmFcMt.wav
# Chuyển đổi thành công: recorded_audio_Wf4mKq1.webm -> recorded_audio_Wf4mKq1.wav
# Chuyển đổi thành công: recorded_audio_Wf9WNgb.webm -> recorded_audio_Wf9WNgb.wav
# Chuyển đổi thành công: recorded_audio_wgQgvN9.webm -> recorded_audio_wgQgvN9.wav
# Chuyển đổi thành công: recorded_audio_wHScvb4.webm -> recorded_audio_wHScvb4.wav
# Chuyển đổi thành công: recorded_audio_WIPJNXe.webm -> recorded_audio_WIPJNXe.wav
# Chuyển đổi thành công: recorded_audio_WiQ6FFg.webm -> recorded_audio_WiQ6FFg.wav
# Chuyển đổi thành công: recorded_audio_Wj40kLb.webm -> recorded_audio_Wj40kLb.wav
# Chuyển đổi thành công: recorded_audio_wjoiwyd.webm -> recorded_audio_wjoiwyd.wav
# Chuyển đổi thành công: recorded_audio_wjw6Ndl.webm -> recorded_audio_wjw6Ndl.wav
# Chuyển đổi thành công: recorded_audio_wjztFXE.webm -> recorded_audio_wjztFXE.wav
# Chuyển đổi thành công: recorded_audio_wlmeikQ.webm -> recorded_audio_wlmeikQ.wav
# Chuyển đổi thành công: recorded_audio_wlQZ3iQ.webm -> recorded_audio_wlQZ3iQ.wav
# Chuyển đổi thành công: recorded_audio_wpOf6dl.webm -> recorded_audio_wpOf6dl.wav
# Chuyển đổi thành công: recorded_audio_WPSpopS.webm -> recorded_audio_WPSpopS.wav
# Chuyển đổi thành công: recorded_audio_Wql0LXM.webm -> recorded_audio_Wql0LXM.wav
# Chuyển đổi thành công: recorded_audio_WtKDjnj.webm -> recorded_audio_WtKDjnj.wav
# Chuyển đổi thành công: recorded_audio_WtYEvaT.webm -> recorded_audio_WtYEvaT.wav
# Chuyển đổi thành công: recorded_audio_WuUnP0R.webm -> recorded_audio_WuUnP0R.wav
# Chuyển đổi thành công: recorded_audio_WV45z7A.webm -> recorded_audio_WV45z7A.wav
# Chuyển đổi thành công: recorded_audio_WvFXQZK.webm -> recorded_audio_WvFXQZK.wav
# Chuyển đổi thành công: recorded_audio_WwUaogu.webm -> recorded_audio_WwUaogu.wav
# Chuyển đổi thành công: recorded_audio_WX3yTDA.webm -> recorded_audio_WX3yTDA.wav
# Chuyển đổi thành công: recorded_audio_wXmff1Y.webm -> recorded_audio_wXmff1Y.wav
# Chuyển đổi thành công: recorded_audio_wy2sae1.webm -> recorded_audio_wy2sae1.wav
# Chuyển đổi thành công: recorded_audio_wy3Jkvt.webm -> recorded_audio_wy3Jkvt.wav
# Chuyển đổi thành công: recorded_audio_WYV0exI.webm -> recorded_audio_WYV0exI.wav
# Chuyển đổi thành công: recorded_audio_x2woP32.webm -> recorded_audio_x2woP32.wav
# Chuyển đổi thành công: recorded_audio_x4Cczv7.webm -> recorded_audio_x4Cczv7.wav
# Chuyển đổi thành công: recorded_audio_X58V6uY.webm -> recorded_audio_X58V6uY.wav
# Chuyển đổi thành công: recorded_audio_x7qZ10e.webm -> recorded_audio_x7qZ10e.wav
# Chuyển đổi thành công: recorded_audio_x8ZgdQ0.webm -> recorded_audio_x8ZgdQ0.wav
# Chuyển đổi thành công: recorded_audio_x9y4SwX.webm -> recorded_audio_x9y4SwX.wav
# Chuyển đổi thành công: recorded_audio_xa5l5D2.webm -> recorded_audio_xa5l5D2.wav
# Chuyển đổi thành công: recorded_audio_XCibfSq.webm -> recorded_audio_XCibfSq.wav
# Chuyển đổi thành công: recorded_audio_xD1sXbm.webm -> recorded_audio_xD1sXbm.wav
# Chuyển đổi thành công: recorded_audio_XdllwSL.webm -> recorded_audio_XdllwSL.wav
# Chuyển đổi thành công: recorded_audio_XF2mfcQ.webm -> recorded_audio_XF2mfcQ.wav
# Chuyển đổi thành công: recorded_audio_xhcMDR3.webm -> recorded_audio_xhcMDR3.wav
# Chuyển đổi thành công: recorded_audio_xHeQ6lW.webm -> recorded_audio_xHeQ6lW.wav
# Chuyển đổi thành công: recorded_audio_XiOefKV.webm -> recorded_audio_XiOefKV.wav
# Chuyển đổi thành công: recorded_audio_xLi779t.webm -> recorded_audio_xLi779t.wav
# Chuyển đổi thành công: recorded_audio_xML4H8F.webm -> recorded_audio_xML4H8F.wav
# Chuyển đổi thành công: recorded_audio_xMqA1De.webm -> recorded_audio_xMqA1De.wav
# Chuyển đổi thành công: recorded_audio_xnaWjtl.webm -> recorded_audio_xnaWjtl.wav
# Chuyển đổi thành công: recorded_audio_xNCWmyp.webm -> recorded_audio_xNCWmyp.wav
# Chuyển đổi thành công: recorded_audio_XPwaOQh.webm -> recorded_audio_XPwaOQh.wav
# Chuyển đổi thành công: recorded_audio_XRAtuhb.webm -> recorded_audio_XRAtuhb.wav
# Chuyển đổi thành công: recorded_audio_XWoW7S8.webm -> recorded_audio_XWoW7S8.wav
# Chuyển đổi thành công: recorded_audio_xxDwyiE.webm -> recorded_audio_xxDwyiE.wav
# Chuyển đổi thành công: recorded_audio_XxNtyxA.webm -> recorded_audio_XxNtyxA.wav
# Chuyển đổi thành công: recorded_audio_XYYpJzs.webm -> recorded_audio_XYYpJzs.wav
# Chuyển đổi thành công: recorded_audio_Xzr8F3R.webm -> recorded_audio_Xzr8F3R.wav
# Chuyển đổi thành công: recorded_audio_y0bd4nx.webm -> recorded_audio_y0bd4nx.wav
# Chuyển đổi thành công: recorded_audio_y4lED35.webm -> recorded_audio_y4lED35.wav
# Chuyển đổi thành công: recorded_audio_y6fBQsp.webm -> recorded_audio_y6fBQsp.wav
# Chuyển đổi thành công: recorded_audio_Y74SPVJ.webm -> recorded_audio_Y74SPVJ.wav
# Chuyển đổi thành công: recorded_audio_y8QuGBT.webm -> recorded_audio_y8QuGBT.wav
# Chuyển đổi thành công: recorded_audio_y90wdZ4.webm -> recorded_audio_y90wdZ4.wav
# Chuyển đổi thành công: recorded_audio_Y9Ax31D.webm -> recorded_audio_Y9Ax31D.wav
# Chuyển đổi thành công: recorded_audio_Y9OkeAf.webm -> recorded_audio_Y9OkeAf.wav
# Chuyển đổi thành công: recorded_audio_ybbS130.webm -> recorded_audio_ybbS130.wav
# Chuyển đổi thành công: recorded_audio_yE5O7sW.webm -> recorded_audio_yE5O7sW.wav
# Chuyển đổi thành công: recorded_audio_yF2h9Sy.webm -> recorded_audio_yF2h9Sy.wav
# Chuyển đổi thành công: recorded_audio_YfDPjXc.webm -> recorded_audio_YfDPjXc.wav
# Chuyển đổi thành công: recorded_audio_yFTJzaP.webm -> recorded_audio_yFTJzaP.wav
# Chuyển đổi thành công: recorded_audio_yfyin0O.webm -> recorded_audio_yfyin0O.wav
# Chuyển đổi thành công: recorded_audio_yg3VR1S.webm -> recorded_audio_yg3VR1S.wav
# Chuyển đổi thành công: recorded_audio_YHfHqtz.webm -> recorded_audio_YHfHqtz.wav
# Chuyển đổi thành công: recorded_audio_yiz5UI2.webm -> recorded_audio_yiz5UI2.wav
# Chuyển đổi thành công: recorded_audio_yj8DJa5.webm -> recorded_audio_yj8DJa5.wav
# Chuyển đổi thành công: recorded_audio_YJ9hASM.webm -> recorded_audio_YJ9hASM.wav
# Chuyển đổi thành công: recorded_audio_YjWGVUB.webm -> recorded_audio_YjWGVUB.wav
# Chuyển đổi thành công: recorded_audio_ysyuZGU.webm -> recorded_audio_ysyuZGU.wav
# Chuyển đổi thành công: recorded_audio_YTbyBUX.webm -> recorded_audio_YTbyBUX.wav
# Chuyển đổi thành công: recorded_audio_YTY08n1.webm -> recorded_audio_YTY08n1.wav
# Chuyển đổi thành công: recorded_audio_Yxs6ugB.webm -> recorded_audio_Yxs6ugB.wav
# Chuyển đổi thành công: recorded_audio_yYQJZaa.webm -> recorded_audio_yYQJZaa.wav
# Chuyển đổi thành công: recorded_audio_z1bzquV.webm -> recorded_audio_z1bzquV.wav
# Chuyển đổi thành công: recorded_audio_Z1Xbh0S.webm -> recorded_audio_Z1Xbh0S.wav
# Chuyển đổi thành công: recorded_audio_z2sp9fN.webm -> recorded_audio_z2sp9fN.wav
# Chuyển đổi thành công: recorded_audio_z2yvcRI.webm -> recorded_audio_z2yvcRI.wav
# Chuyển đổi thành công: recorded_audio_Z51909t.webm -> recorded_audio_Z51909t.wav
# Chuyển đổi thành công: recorded_audio_Z5eKskP.webm -> recorded_audio_Z5eKskP.wav
# Chuyển đổi thành công: recorded_audio_z5kzN6c.webm -> recorded_audio_z5kzN6c.wav
# Chuyển đổi thành công: recorded_audio_Z6kyVNw.webm -> recorded_audio_Z6kyVNw.wav
# Chuyển đổi thành công: recorded_audio_z6NhvPD.webm -> recorded_audio_z6NhvPD.wav
# Chuyển đổi thành công: recorded_audio_Z6wPvGH.webm -> recorded_audio_Z6wPvGH.wav
# Chuyển đổi thành công: recorded_audio_Z78h3d0.webm -> recorded_audio_Z78h3d0.wav
# Chuyển đổi thành công: recorded_audio_zajTn7g.webm -> recorded_audio_zajTn7g.wav
# Chuyển đổi thành công: recorded_audio_ZAwRbrx.webm -> recorded_audio_ZAwRbrx.wav
# Chuyển đổi thành công: recorded_audio_zax6QET.webm -> recorded_audio_zax6QET.wav
# Chuyển đổi thành công: recorded_audio_zbjuKLe.webm -> recorded_audio_zbjuKLe.wav
# Chuyển đổi thành công: recorded_audio_ZC7DKS0.webm -> recorded_audio_ZC7DKS0.wav
# Chuyển đổi thành công: recorded_audio_ZCaI5MH.webm -> recorded_audio_ZCaI5MH.wav
# Chuyển đổi thành công: recorded_audio_Zh2xOcm.webm -> recorded_audio_Zh2xOcm.wav
# Chuyển đổi thành công: recorded_audio_Zh5XrM6.webm -> recorded_audio_Zh5XrM6.wav
# Chuyển đổi thành công: recorded_audio_ziejPvS.webm -> recorded_audio_ziejPvS.wav
# Chuyển đổi thành công: recorded_audio_zIYcFyT.webm -> recorded_audio_zIYcFyT.wav
# Chuyển đổi thành công: recorded_audio_ZJ7BcZu.webm -> recorded_audio_ZJ7BcZu.wav
# Chuyển đổi thành công: recorded_audio_zJfQqSL.webm -> recorded_audio_zJfQqSL.wav
# Chuyển đổi thành công: recorded_audio_zjK4uvM.webm -> recorded_audio_zjK4uvM.wav
# Chuyển đổi thành công: recorded_audio_zjyoKEz.webm -> recorded_audio_zjyoKEz.wav
# Chuyển đổi thành công: recorded_audio_zkstsWP.webm -> recorded_audio_zkstsWP.wav
# Chuyển đổi thành công: recorded_audio_zlcKyaj.webm -> recorded_audio_zlcKyaj.wav
# Chuyển đổi thành công: recorded_audio_zLpEd12.webm -> recorded_audio_zLpEd12.wav
# Chuyển đổi thành công: recorded_audio_ZopHHrM.webm -> recorded_audio_ZopHHrM.wav
# Chuyển đổi thành công: recorded_audio_zpcGac1.webm -> recorded_audio_zpcGac1.wav
# Chuyển đổi thành công: recorded_audio_ZPjdi0o.webm -> recorded_audio_ZPjdi0o.wav
# Chuyển đổi thành công: recorded_audio_ZQw4kbg.webm -> recorded_audio_ZQw4kbg.wav
# Chuyển đổi thành công: recorded_audio_zSVMDUF.webm -> recorded_audio_zSVMDUF.wav
# Chuyển đổi thành công: recorded_audio_ZZEg59R.webm -> recorded_audio_ZZEg59R.wav
# Chuyển đổi thành công: recorded_audio_ZzzSe40.webm -> recorded_audio_ZzzSe40.wav
